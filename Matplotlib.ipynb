# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot();
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[10,25,36,50]
plt.plot(x,y);

# %%
# 1st Method
fig = plt.figure() # creates figure
ax = fig.add_subplot() # add some axes
plt.show()

# %%
# 2nd Method
fig = plt.figure() # Create figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y) # Add some Data
plt.show();

# %%
# 3rd Method (Recommended)
fig,ax=plt.subplots()
ax.plot(x,y); # Add some data

# %% [markdown]
# # Matplotlib example workflow

# %%
# 0. Import matplotlib and get it ready for plotting in jupyter.
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1,3,5,7]
y = [10,15,23,30]

# 2. Setup plot
fig,ax =plt.subplots(figsize=(10,10)) # Fig Size means Width and height

# 3. Plot data
ax.plot(x,y);

# 4. Customize Plot

ax.set(title="Sample Plot",
      xlabel="x-axis",
      ylabel="y-axis")

# 5. Save & show ( You should save the whole figure)
fig.savefig("../Matplotlib/sample-plot.png")

# %% [markdown]
# ## Making figure using NumPy array
#
# We Want:
# * Line plot
# * Bar plot
# * scatter plot
# * Histogram
# * Subplots

# %%
# Create some data
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a Line plot
fig,ax=plt.subplots()
ax.plot(x, x**2);

# %%
# Use same data to make Scatter Plot
fig,ax=plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Another Scatter Plot
fig,ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a Bar Plot from a Dictionary.
nut_butter_prices={"Almond Butter":15,
                  "Peanut Butter":8,
                  "Chasew Butter":20}
fig,ax=plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title='Minhaz Nut Butter Store',
      ylabel="Prices ($)");

# %%
# Horizontal Bar graph
fig,ax=plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values())); # For horizontal graph you have to use list.

# %%
# Make some data and create a Histogram
x = np.random.randn(1000)
fig,ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Two option for Subplots

# %%
# Subplots Option 1
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,
                                      ncols=2,
                                      figsize=(10,5))
# Plot to each different axis
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax4.hist(np.random.randn(1000));

# %%
# Subplots Option 2

fig,ax=plt.subplots(nrows=2,
                   ncols=2,
                   figsize=(10,5))

# Plot to each different index.

ax[0,0].plot(x, x/2)
ax[0,1].scatter(np.random.random(10), np.random.random(10))
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Ploting From Pandas DataFrame

# %%
# Make a DataFrame
car_sales = pd.read_csv('car-sales-mt.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
np.random.seed(2)
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range("1/1/2024",periods=1000))
ts=ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','', regex=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
car_sales['Price']=car_sales['Price'].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"]=pd.date_range('1/1/2023',periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2023-01-01
# 1   Honda    Red          87899      4   5000 2023-01-02
# 2  Toyota   Blue          32549      3   7000 2023-01-03
# 3     BMW  Black          11179      5  22000 2023-01-04
# 4  Nissan  White         213095      4   3500 2023-01-05
# 5  Toyota  Green          99213      4   4500 2023-01-06
# 6   Honda   Blue          45698      4   7500 2023-01-07
# 7   Honda   Blue          54738      4   7000 2023-01-08
# 8  Toyota  White          60000      4   6250 2023-01-09
# 9  Nissan  White          31600      4   9700 2023-01-10

# %%
#car_sales['Total']=car_sales['Price'].cumsum() #As the price column is in string format that's why it is just concatenated.
car_sales['Total Sale'] = car_sales['Price'].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sale
# 0  Toyota  White         150043      4   4000 2023-01-01        4000
# 1   Honda    Red          87899      4   5000 2023-01-02        9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03       16000
# 3     BMW  Black          11179      5  22000 2023-01-04       38000
# 4  Nissan  White         213095      4   3500 2023-01-05       41500
# 5  Toyota  Green          99213      4   4500 2023-01-06       46000
# 6   Honda   Blue          45698      4   7500 2023-01-07       53500
# 7   Honda   Blue          54738      4   7000 2023-01-08       60500
# 8  Toyota  White          60000      4   6250 2023-01-09       66750
# 9  Nissan  White          31600      4   9700 2023-01-10       76450

# %%
type(car_sales['Price'][0])
# Out:
# str

# %%
# Lets Plot the total sale.
car_sales.plot(x='Sale Date', y='Total Sale');

# %%
# Reasign Price column to int
car_sales['Price']=car_sales["Price"].astype(int)
car_sales.plot(x='Odometer (KM)',y='Price',kind='scatter');
# Out:
# C:\Users\Mas85\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# How about a Bar graph?
x=np.random.rand(10,4)

# Trun it into a DataFrame.
df=pd.DataFrame(x,columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0  0.251059  0.131836  0.145260  0.591164
# 1  0.390762  0.708039  0.083368  0.016464
# 2  0.960264  0.090794  0.345633  0.018787
# 3  0.883465  0.846842  0.588550  0.158628
# 4  0.801517  0.067642  0.457112  0.315828
# 5  0.997135  0.977741  0.831079  0.451059
# 6  0.502600  0.551595  0.559026  0.182086
# 7  0.201282  0.706138  0.846163  0.959511
# 8  0.760845  0.554835  0.085577  0.085535
# 9  0.152577  0.706183  0.278163  0.423252

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total  Total Sale
# 0  Toyota  White         150043      4   4000 2023-01-01   4000        4000
# 1   Honda    Red          87899      4   5000 2023-01-02   9000        9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03  16000       16000
# 3     BMW  Black          11179      5  22000 2023-01-04  38000       38000
# 4  Nissan  White         213095      4   3500 2023-01-05  41500       41500
# 5  Toyota  Green          99213      4   4500 2023-01-06  46000       46000
# 6   Honda   Blue          45698      4   7500 2023-01-07  53500       53500
# 7   Honda   Blue          54738      4   7000 2023-01-08  60500       60500
# 8  Toyota  White          60000      4   6250 2023-01-09  66750       66750
# 9  Nissan  White          31600      4   9700 2023-01-10  76450       76450

# %%
car_sales.plot(x='Make',y='Odometer (KM)',kind='bar');

# %%
# How about Histograms?
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=30);

# %%
# Let's try with some different data.
heart_disease=pd.read_csv('../heart-disease.csv')
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
# Create a histogram of age.
heart_disease["age"].plot.hist(bins=20);

# %%
heart_disease.plot.hist(figsize=(10,40),subplots=True);

# %% [markdown]
# ### Which one should you used?(Pyplot or matplotlib OO method?)
# * When plotting something quickly, it is okay to use Pyplot.
# * When Plotting something advanced, use the Object Oriented (OO) method.

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Pyplot Method
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target");

# %%
# OO method mixed with Pyplot method.
fig,ax=plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            ax=ax);
# ax.set_xlim([45,100]);

# %%
# OO method from scratch.
fig,ax=plt.subplots(figsize=(10,6))

# Plot the data
scatter=ax.scatter(x=over_50["age"],
                  y=over_50["chol"],
                 c=over_50["target"] )

# Customize the plot.
ax.set(title="Heart Disease and Cholestrol Level",
      xlabel="Age",
      ylabel="Cholestrol")

# Add a Legend.
ax.legend(*scatter.legend_elements(),title="Target")

# Add a horizontal line.
ax.axhline(over_50["chol"].mean(),
           color='black',
          linestyle='--');

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplots of chol, age, and thalach.
fig,(ax0,ax1)=plt.subplots(nrows=2,
                          ncols=1,
                          figsize=(10,10),
                           #sharex=True (To use the x axis for two subplots. you have to remove xlabel from ax0)
                          ) 

                          

# Add some data to ax0.
scatter =ax0.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"])

# Customize the ax0 Plot.
ax0.set(xlabel="Age",
       ylabel="Cholestrol",
       title="Heart Disease and Cholestrol Levels.")

# Add a legend.
ax0.legend(*scatter.legend_elements(),title="Target")

# Add a meanline.
ax0.axhline(y=over_50["chol"].mean(),
           c="black",
           linestyle="--");


# Plot for Thalach column.
scatter= ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"])

# Customize the ax1 plot.
ax1.set(title="Heart Disease and Max Heart Rate.",
       xlabel="Age",
       ylabel="Max Heart Rate")

# Add legend for thalach.
ax1.legend(*scatter.legend_elements(),title="Target")

# Add a Meanline.
ax1.axhline(y=over_50["thalach"].mean(),
           color="black",
           linestyle="--")

# Add a title to the figure.
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %% [markdown]
# ## Customizing Matplotlib and getting stylish

# %%
## See the different styles available.
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sale
# 0  Toyota  White         150043      4   4000 2023-01-01        4000
# 1   Honda    Red          87899      4   5000 2023-01-02        9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03       16000
# 3     BMW  Black          11179      5  22000 2023-01-04       38000
# 4  Nissan  White         213095      4   3500 2023-01-05       41500

# %%
car_sales["Price"].astype(int).plot();

# %%
plt.style.use('seaborn-v0_8-notebook')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-v0_8-ticks')

# %%
car_sales["Price"].astype(int).plot();

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter",figsize=(10,7));
# Out:
# C:\Users\Mas85\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# Create some data.
x=np.random.randn(10,4)
x
# Out:
# array([[-1.60424336e+00, -1.26915438e+00,  3.19229394e-01,
#         -1.68372297e+00],
#        [-6.64211308e-01, -7.82832806e-01,  2.18506368e-01,
#         -1.96094155e-01],
#        [ 1.20420159e-03,  1.10557793e+00, -5.73954240e-03,
#         -3.42204139e-01],
#        [ 1.00161944e+00,  1.01925350e-01,  5.28404338e-01,
#         -1.61170258e+00],
#        [-9.04002209e-01, -4.41820133e-01,  1.65815823e+00,
#         -6.43042751e-01],
#        [ 2.05703949e-01,  1.98066743e-01,  2.18383530e+00,
#         -1.04722527e+00],
#        [-8.86691968e-01, -3.99070487e-01,  8.53231109e-01,
#          3.81288238e-01],
#        [ 6.63243083e-01,  1.70039522e+00, -7.09365781e-01,
#          2.03758772e+00],
#        [-8.20074168e-01,  1.18510402e-01, -6.05132378e-01,
#          1.22732774e+00],
#        [-8.86801487e-01, -7.30615157e-01, -5.40253915e-01,
#          1.27408512e-01]])

# %%
df = pd.DataFrame(x,columns=['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0 -1.604243 -1.269154  0.319229 -1.683723
# 1 -0.664211 -0.782833  0.218506 -0.196094
# 2  0.001204  1.105578 -0.005740 -0.342204
# 3  1.001619  0.101925  0.528404 -1.611703
# 4 -0.904002 -0.441820  1.658158 -0.643043

# %%
ax=df.plot(kind='bar')
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
ax=df.plot(kind="bar")
# Customize the plot using set method
ax.set(title="Random Graph",
      xlabel="Rand X ",
      ylabel="Random Y")

# Add legend
ax.legend().set_visible(True);

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Set the style
plt.style.use('seaborn-v0_8-whitegrid')

# OO method from scratch.
fig,ax=plt.subplots(figsize=(10,6))

# Plot the data
scatter=ax.scatter(x=over_50["age"],
                  y=over_50["chol"],
                 c=over_50["target"],
                  cmap='winter') # This changes the color scheme..

# Customize the plot.
ax.set(title="Heart Disease and Cholestrol Level",
      xlabel="Age",
      ylabel="Cholestrol")

# Add a Legend.
ax.legend(*scatter.legend_elements(),title="Target")

# Add a horizontal line.
ax.axhline(over_50["chol"].mean(),
           color='black',
          linestyle='--');

# %%
# Customizing the Y and X axis limitations.

# Subplots of chol, age, and thalach.
fig,(ax0,ax1)=plt.subplots(nrows=2,
                          ncols=1,
                          figsize=(10,10),
                           #sharex=True (To use the x axis for two subplots. you have to remove xlabel from ax0)
                          ) 

                          

# Add some data to ax0.
scatter =ax0.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"],
                    cmap='winter')

# Customize the ax0 Plot.
ax0.set(xlabel="Age",
       ylabel="Cholestrol",
       title="Heart Disease and Cholestrol Levels.")

# Change the ax0 x axis limits.
ax0.set_xlim([50,80])

# Add a legend.
ax0.legend(*scatter.legend_elements(),title="Target")

# Add a meanline.
ax0.axhline(y=over_50["chol"].mean(),
           c="black",
           linestyle="--");


# Plot for Thalach column.
scatter= ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"],
                    cmap='spring')

# Customize the ax1 plot.
ax1.set(title="Heart Disease and Max Heart Rate.",
       xlabel="Age",
       ylabel="Max Heart Rate")

# Change the ax1 and y axis limits.
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])

# Add legend for thalach.
ax1.legend(*scatter.legend_elements(),title="Target")

# Add a Meanline.
ax1.axhline(y=over_50["thalach"].mean(),
           color="black",
           linestyle="--")

# Add a title to the figure.
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %%
# To show the figure and share 
fig

# %%
fig.savefig("heart-disease-analysis-code-with-figure.png")
